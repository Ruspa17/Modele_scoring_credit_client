# %% [markdown]
# # Import Data

# %%
# Data manipulation
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Evaluation of the model
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score
from sklearn.metrics import classification_report

import pickle

plt.rcParams['font.size'] = 18

# %%
train = pd.read_csv('../Dataset/train_small.csv')
test = pd.read_csv('../Dataset/test_small.csv')

print('Train shape: ', train.shape)
print('Test shape: ', test.shape)
# Out:
# Train shape:  (307511, 280)
# Test shape:  (48744, 279)

# %% [markdown]
# # Import model, test and metrics

# %%
# Extract the labels
labels = train['TARGET']
features = train.drop(columns=['TARGET', 'SK_ID_CURR'])

# Split into training and testing data
train_features, test_features, train_labels, test_labels = train_test_split(
    features, labels, test_size=0.25, random_state=17)

print('Train shape: ', train_features.shape)
print('Test shape: ', test_features.shape)

train_features.head()
# Out:
# Train shape:  (230633, 278)
# Test shape:  (76878, 278)
#         CREDIT_TERM  EXT_SOURCE_1  EXT_SOURCE_2  EXT_SOURCE_3  DAYS_EMPLOYED  \
# 89672      0.102457      0.719170      0.541840      0.472253        -8093.0
# 238736     0.061293           NaN      0.615644      0.185202        -5438.0
# 278307     0.051056      0.391970      0.323001      0.461482        -1551.0
# 181026     0.050000           NaN      0.705380      0.636376         -358.0
# 66008      0.048328      0.656476      0.477630           NaN        -1456.0
#
#         DAYS_BIRTH  client_installments_payments_AMT_PAYMENT_min_sum  \
# 89672        16834                                         65330.550
# 238736       15884                                         31119.480
# 278307       10730                                         40367.703
# 181026       15654                                        162577.530
# 66008        19008                                         68668.160
#
#         AMT_ANNUITY  client_pos_cash_CNT_INSTALMENT_FUTURE_mean_max  \
# 89672       16137.0                                        6.818182
# 238736       9252.0                                       36.000000
# 278307      41355.0                                        3.000000
# 181026      19125.0                                        8.000000
# 66008       28530.0                                       20.000000
#
#         bureau_DAYS_CREDIT_max  ...  \
# 89672                   -126.0  ...
# 238736                   -82.0  ...
# 278307                  -376.0  ...
# 181026                  -131.0  ...
# 66008                      NaN  ...
#
#         client_installments_payments_NUM_INSTALMENT_VERSION_sum_sum  \
# 89672                                               110.0
# 238736                                               91.0
# 278307                                               36.0
# 181026                                              169.0
# 66008                                                81.0
#
#         previous_NAME_GOODS_CATEGORY_ConsumerElectronics_mean  \
# 89672                                                 0.0
# 238736                                                0.0
# 278307                                                0.0
# 181026                                                0.0
# 66008                                                 0.5
#
#         client_credit_card_AMT_CREDIT_LIMIT_ACTUAL_min_sum  \
# 89672                                                 NaN
# 238736                                                NaN
# 278307                                                NaN
# 181026                                                NaN
# 66008                                            405000.0
#
#         client_credit_card_SK_DPD_mean_min  \
# 89672                                  NaN
# 238736                                 NaN
# 278307                                 NaN
# 181026                                 NaN
# 66008                                  0.0
#
#         bureau_CREDIT_ACTIVE_Sold_count_norm  \
# 89672                                    0.0
# 238736                                   0.0
# 278307                                   0.0
# 181026                                   0.0
# 66008                                    NaN
#
#         client_bureau_balance_MONTHS_BALANCE_count_max  \
# 89672                                             36.0
# 238736                                             9.0
# 278307                                            80.0
# 181026                                             NaN
# 66008                                              NaN
#
#         previous_NAME_CLIENT_TYPE_New_mean  \
# 89672                                  1.0
# 238736                                 0.5
# 278307                                 1.0
# 181026                                 0.5
# 66008                                  1.0
#
#         previous_CODE_REJECT_REASON_LIMIT_mean  \
# 89672                                      0.0
# 238736                                     0.0
# 278307                                     0.0
# 181026                                     0.0
# 66008                                      0.0
#
#         client_credit_card_AMT_DRAWINGS_ATM_CURRENT_sum_sum  \
# 89672                                                 NaN
# 238736                                                NaN
# 278307                                                NaN
# 181026                                                NaN
# 66008                                            668250.0
#
#         previous_WEEKDAY_APPR_PROCESS_START_TUESDAY_mean
# 89672                                                0.0
# 238736                                               0.0
# 278307                                               0.0
# 181026                                               0.0
# 66008                                                0.0
#
# [5 rows x 278 columns]

# %%
with open('Final_Model.pkl', 'rb') as file:
    Final_Model = pickle.load(file)

# %%
preds_proba = Final_Model.predict_proba(test_features)[:, 1]
preds = Final_Model.predict(test_features)

rus_auc = roc_auc_score(test_labels, preds_proba)

print('The random undersampling model scores {:.5f} ROC AUC on the test set.'.format(
    rus_auc))
print()
print(classification_report(test_labels, preds))
# Out:
# The random undersampling model scores 0.77735 ROC AUC on the test set.
#
#               precision    recall  f1-score   support
#
#            0       0.96      0.71      0.82     70622
#            1       0.18      0.70      0.28      6256
#
#     accuracy                           0.71     76878
#    macro avg       0.57      0.70      0.55     76878
# weighted avg       0.90      0.71      0.77     76878

# %% [markdown]
# # SHAP Values

# %%
# use 1 row of data here. Could use multiple rows if desired
data_for_prediction = test_features.iloc[0]
data_for_prediction_array = data_for_prediction.values.reshape(1, -1)

# %%
Final_Model.predict_proba(data_for_prediction_array)
# Out:
# array([[0.90978529, 0.09021471]])

# %%
import shap

shap.initjs()

# Create object that can calculate shap values
explainer = shap.TreeExplainer(Final_Model)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>!function(t){function e(r){if(n[r])return n[r].exports;var i=n[r]={i:r,l:!1,exports:{}};return t[r].call(i.exports,i,i.exports,e),i.l=!0,i.exports}var n={};return e.m=t,e.c=n,e.i=function(t){return t},e.d=function(t,n,r){e.o(t,n)||Object.defineProperty(t,n,{configurable:!1,enumerable:!0,get:r})},e.n=function(t){var n=t&&t.__esModule?function(){return t.default}:function(){return t};return e.d(n,"a",n),n},e.o=function(t,e){return Object.prototype.hasOwnProperty.call(t,e)},e.p="",e(e.s=410)}([function(t,e,n){"use strict";function r(t,e,n,r,o,a,u,c){if(i(e),!t){var s;if(void 0===e)s=new Error("Minified exception occurred; use the non-minified dev environment for the full error message and additional helpful warnings.");else{var l=[n,r,o,a,u,c],f=0;s=new Error(e.replace(/%s/g,function(){return l[f++]})),s.name="Invariant Violation"}throw s.framesToPop=1,s}}var i=function(t){};t.exports=r},function(t,e,n){"use strict";var r=n(8),i=r;t.exports=i},function(t,e,n){"use strict";function r(t){for(var e=arguments.length-1,n="Minified React error #"+t+"; visit http://facebook.github.io/react/docs/error-decoder.html?invariant="+t,r=0;r<e;r++)n+="&args[]="+encodeURIComponent(arguments[r+1]);n+=" for the full message or use the non-minified dev environment for full errors and additional helpful warnings.";var i=new Error(n);throw i.name="Invariant Violation",i.framesToPop=1,i}t.exports=r},function(t,e,n){"use strict";function r(t){if(null===t||void 0===t)throw new TypeError("Object.assign cannot be called with null or undefined");return Object(t)}function i(){try{if(!Object.assign)return!1;var t=new String("abc");if(t[5]="de","5"===Object.getOwnPropertyNames(t)[0])return!1;for(var e={},n=0;n<10;n++)e["_"+String.fromCharCode(n)]=n;var r=Object.getOwnPropertyNames(e).map(function(t){return e[t]});if("0123456789"!==r.join(""))return!1;var i={};return"abcdefghijklmnopqrst".split("").forEach(function(t){i[t]=t}),"abcdefghijklmnopqrst"===Object.keys(Object.assign({},i)).join("")}catch(t){return!1}}/*
# object-assign
# (c) Sindre Sorhus
# @license MIT
# */
# var o=Object.getOwnPropertySymbols,a=Object.prototype.hasOwnProperty,u=Object.prototype.propertyIsEnumerable;t.exports=i()?Object.assign:function(t,e){for(var n,i,c=r(t),s=1;s<arguments.length;s++){n=Object(arguments[s]);for(var l in n)a.call(n,l)&&(c[l]=n[l]);if(o){i=o(n);for(var f=0;f<i.length;f++)u.call(n,i[f])&&(c[i[f]]=n[i[f]])}}return c}},function(t,e,n){"use strict";function r(t,e){return 1===t.nodeType&&t.getAttribute(d)===String(e)||8===t.nodeType&&t.nodeValue===" react-text: "+e+" "||8===t.nodeType&&t.nodeValue===" react-empty: "+e+" "}function i(t){for(var e;e=t._renderedComponent;)t=e;return t}function o(t,e){var n=i(t);n._hostNode=e,e[g]=n}function a(t){var e=t._hostNode;e&&(delete e[g],t._hostNode=null)}function u(t,e){if(!(t._flags&v.hasCachedChildNodes)){var n=t._renderedChildren,a=e.firstChild;t:for(var u in n)if(n.hasOwnProperty(u)){var c=n[u],s=i(c)._domID;if(0!==s){for(;null!==a;a=a.nextSibling)if(r(a,s)){o(c,a);continue t}f("32",s)}}t._flags|=v.hasCachedChildNodes}}function c(t){if(t[g])return t[g];for(var e=[];!t[g];){if(e.push(t),!t.parentNode)return null;t=t.parentNode}for(var n,r;t&&(r=t[g]);t=e.pop())n=r,e.length&&u(r,t);return n}function s(t){var e=c(t);return null!=e&&e._hostNode===t?e:null}function l(t){if(void 0===t._hostNode?f("33"):void 0,t._hostNode)return t._hostNode;for(var e=[];!t._hostNode;)e.push(t),t._hostParent?void 0:f("34"),t=t._hostParent;for(;e.length;t=e.pop())u(t,t._hostNode);return t._hostNode}var f=n(2),p=n(21),h=n(157),d=(n(0),p.ID_ATTRIBUTE_NAME),v=h,g="__reactInternalInstance$"+Math.random().toString(36).slice(2),m={getClosestInstanceFromNode:c,getInstanceFromNode:s,getNodeFromInstance:l,precacheChildNodes:u,precacheNode:o,uncacheNode:a};t.exports=m},function(t,e,n){"use strict";function r(t,e,n,a){function u(e){return t(e=new Date(+e)),e}return u.floor=u,u.ceil=function(n){return t(n=new Date(n-1)),e(n,1),t(n),n},u.round=function(t){var e=u(t),n=u.ceil(t);return t-e<n-t?e:n},u.offset=function(t,n){return e(t=new Date(+t),null==n?1:Math.floor(n)),t},u.range=function(n,r,i){var o=[];if(n=u.ceil(n),i=null==i?1:Math.floor(i),!(n<r&&i>0))return o;do o.push(new Date(+n));while(e(n,i),t(n),n<r);return o},u.filter=function(n){return r(function(e){if(e>=e)for(;t(e),!n(e);)e.setTime(e-1)},function(t,r){if(t>=t)for(;--r>=0;)for(;e(t,1),!n(t););})},n&&(u.count=function(e,r){return i.setTime(+e),o.setTime(+r),t(i),t(o),Math.floor(n(i,o))},u.every=function(t){return t=Math.floor(t),isFinite(t)&&t>0?t>1?u.filter(a?function(e){return a(e)%t===0}:function(e){return u.count(0,e)%t===0}):u:null}),u}e.a=r;var i=new Date,o=new Date},function(t,e,n){"use strict";var r=!("undefined"==typeof window||!window.document||!window.document.createElement),i={canUseDOM:r,canUseWorkers:"undefined"!=typeof Worker,canUseEventListeners:r&&!(!window.addEventListener&&!window.attachEvent),canUseViewport:r&&!!window.screen,isInWorker:!r};t.exports=i},function(t,e,n){"use strict";function r(t,e){this._groups=t,this._parents=e}function i(){return new r([[document.documentElement]],D)}var o=n(272),a=n(273),u=n(261),c=n(255),s=n(131),l=n(260),f=n(265),p=n(268),h=n(275),d=n(253),v=n(267),g=n(266),m=n(274),y=n(259),_=n(258),b=n(252),x=n(276),w=n(269),C=n(254),M=n(277),k=n(262),E=n(270),T=n(264),S=n(251),P=n(263),N=n(271),A=n(256),O=n(70),I=n(257);n.d(e,"c",function(){return D}),e.b=r;var D=[null];r.prototype=i.prototype={constructor:r,select:o.a,selectAll:a.a,filter:u.a,data:c.a,enter:s.a,exit:l.a,merge:f.a,order:p.a,sort:h.a,call:d.a,nodes:v.a,node:g.a,size:m.a,empty:y.a,each:_.a,attr:b.a,style:x.a,property:w.a,classed:C.a,text:M.a,html:k.a,raise:E.a,lower:T.a,append:S.a,insert:P.a,remove:N.a,datum:A.a,on:O.c,dispatch:I.a},e.a=i},function(t,e,n){"use strict";function r(t){return function(){return t}}var i=function(){};i.thatReturns=r,i.thatReturnsFalse=r(!1),i.thatReturnsTrue=r(!0),i.thatReturnsNull=r(null),i.thatReturnsThis=function(){return this},i.thatReturnsArgument=function(t){return t},t.exports=i},function(t,e,n ...

# %%
shap_values = explainer.shap_values(data_for_prediction_array)
shap.force_plot(explainer.expected_value[1],
                shap_values[1], data_for_prediction)
# Out:
# LightGBM binary classifier with TreeExplainer shap values output has changed to a list of ndarray
# <div id='iH12EJKQNKRZV64JLWBCQ'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.0019249266254182662, "outValue": -2.3110161381058827, "link": "identity", "featureNames": ["CREDIT_TERM", "EXT_SOURCE_1", "EXT_SOURCE_2", "EXT_SOURCE_3", "DAYS_EMPLOYED", "DAYS_BIRTH", "client_installments_payments_AMT_PAYMENT_min_sum", "AMT_ANNUITY", "client_pos_cash_CNT_INSTALMENT_FUTURE_mean_max", "bureau_DAYS_CREDIT_max", "bureau_DAYS_CREDIT_ENDDATE_max", "bureau_AMT_CREDIT_MAX_OVERDUE_mean", "DAYS_ID_PUBLISH", "OWN_CAR_AGE", "AMT_CREDIT", "bureau_AMT_CREDIT_SUM_DEBT_mean", "ANNUITY_INCOME_PERCENT", "client_installments_payments_AMT_PAYMENT_min_mean", "CODE_GENDER_F", "bureau_DAYS_ENDDATE_FACT_max", "DAYS_REGISTRATION", "REGION_POPULATION_RELATIVE", "client_pos_cash_CNT_INSTALMENT_FUTURE_min_max", "DAYS_LAST_PHONE_CHANGE", "previous_HOUR_APPR_PROCESS_START_mean", "bureau_AMT_CREDIT_SUM_mean", "client_pos_cash_CNT_INSTALMENT_FUTURE_mean_mean", "client_credit_card_CNT_DRAWINGS_CURRENT_mean_min", "previous_CNT_PAYMENT_mean", "client_installments_payments_AMT_PAYMENT_min_min", "bureau_AMT_CREDIT_SUM_max", "previous_AMT_DOWN_PAYMENT_max", "client_pos_cash_SK_DPD_DEF_mean_mean", "YEARS_BEGINEXPLUATATION_AVG", "previous_SELLERPLACE_AREA_max", "bureau_DAYS_CREDIT_mean", "bureau_DAYS_CREDIT_UPDATE_max", "bureau_AMT_CREDIT_SUM_sum", "client_installments_payments_DAYS_ENTRY_PAYMENT_sum_max", "previous_RATE_DOWN_PAYMENT_sum", "CREDIT_INCOME_PERCENT", "client_installments_payments_AMT_PAYMENT_min_max", "previous_RATE_DOWN_PAYMENT_max", "client_installments_payments_AMT_PAYMENT_sum_mean", "NAME_FAMILY_STATUS_Married", "previous_NAME_YIELD_GROUP_high_mean", "previous_NAME_CONTRACT_STATUS_Refused_mean", "APARTMENTS_AVG", "client_installments_payments_AMT_INSTALMENT_max_max", "client_installments_payments_AMT_INSTALMENT_min_sum", "client_installments_payments_NUM_INSTALMENT_VERSION_mean_max", "client_installments_payments_NUM_INSTALMENT_VERSION_mean_mean", "client_pos_cash_CNT_INSTALMENT_FUTURE_mean_min", "client_installments_payments_AMT_PAYMENT_sum_sum", "previous_DAYS_DECISION_max", "previous_NAME_YIELD_GROUP_low_action_mean", "previous_CNT_PAYMENT_sum", "bureau_DAYS_CREDIT_ENDDATE_mean", "previous_PRODUCT_COMBINATION_CashXSelllow_mean", "client_pos_cash_CNT_INSTALMENT_FUTURE_min_mean", "bureau_AMT_CREDIT_SUM_LIMIT_mean", "NAME_EDUCATION_TYPE_Highereducation", "REGION_RATING_CLIENT", "bureau_DAYS_CREDIT_min", "bureau_CREDIT_ACTIVE_Active_count", "client_installments_payments_AMT_PAYMENT_sum_max", "bureau_AMT_CREDIT_SUM_min", "bureau_DAYS_CREDIT_ENDDATE_sum", "COMMONAREA_AVG", "BASEMENTAREA_AVG", "bureau_AMT_CREDIT_SUM_DEBT_max", "AMT_INCOME_TOTAL", "bureau_DAYS_CREDIT_sum", "client_installments_payments_DAYS_ENTRY_PAYMENT_min_mean", "previous_PRODUCT_COMBINATION_POSindustrywithinterest_mean", "client_installments_payments_AMT_PAYMENT_mean_max", "client_pos_cash_NAME_CONTRACT_STATUS_Active_sum_mean", "client_installments_payments_AMT_PAYMENT_mean_min", "client_installments_payments_AMT_INSTALMENT_max_min", "previous_DAYS_DECISION_mean", "bureau_CREDIT_ACTIVE_Active_count_norm", "bureau_CREDIT_TYPE_Mortgage_count_norm", "LANDAREA_AVG", "previous_AMT_ANNUITY_min", "client_installments_payments_NUM_INSTALMENT_VERSION_sum_mean", "bureau_DAYS_ENDDATE_FACT_min", "previous_CNT_PAYMENT_max", "NONLIVINGAREA_AVG", "bureau_DAYS_CREDIT_UPDATE_mean", "client_installments_payments_AMT_PAYMENT_sum_min", "previous_AMT_ANNUITY_max", "bureau_DAYS_ENDDATE_FACT_mean", "client_installments_payments_NUM_INSTALMENT_VERSION_sum_max", "bureau_DAYS_CREDIT_UPDATE_min", "client_pos_cash_MONTHS_BALANCE_min_max", "previous_DAYS_LAST_DUE_1ST_VERSION_sum", "FLAG_DOCUMENT_3", "previous_NAME_TYPE_SUITE_Unaccompanied_mean", "previous_DAYS_LAST_DUE_sum", "client_pos_cash_MONTHS_BALANCE_sum_min", "previous_NAME_CONTRACT_STATUS_Approved_mean", "previous_AMT_DOWN_PAYMENT_mean", "previous_AMT_ANNUITY_mean", "previous_AMT_CREDIT_mean", "NAME_CONTRACT_TYPE", "client_pos_cash_CNT_INST ...

# %%
shap_values = explainer.shap_values(test_features)
shap.summary_plot(shap_values[1], test_features)

# %%
shap.summary_plot(shap_values, test_features)

# %%
shap_sum = np.abs(shap_values[0]).mean(axis=0)

importance_df = pd.DataFrame([test_features.columns.tolist(), shap_sum.tolist()]).T
importance_df.columns = ['column_name', 'shap_importance']
importance_df = importance_df.sort_values('shap_importance', ascending=False)

importance_df.head(15)
# Out:
#                                          column_name shap_importance
# 2                                       EXT_SOURCE_2        0.347796
# 3                                       EXT_SOURCE_3        0.328416
# 1                                       EXT_SOURCE_1        0.157944
# 18                                     CODE_GENDER_F        0.141039
# 0                                        CREDIT_TERM        0.122925
# 4                                      DAYS_EMPLOYED        0.102968
# 7                                        AMT_ANNUITY        0.095364
# 15                   bureau_AMT_CREDIT_SUM_DEBT_mean        0.081279
# 44                        NAME_FAMILY_STATUS_Married        0.075037
# 6   client_installments_payments_AMT_PAYMENT_min_sum        0.074837
# 5                                         DAYS_BIRTH        0.074224
# 13                                       OWN_CAR_AGE        0.073025
# 61               NAME_EDUCATION_TYPE_Highereducation        0.063188
# 8     client_pos_cash_CNT_INSTALMENT_FUTURE_mean_max        0.061712
# 46        previous_NAME_CONTRACT_STATUS_Refused_mean         0.05518

# %%
most_important_var = importance_df['column_name'][0:5].tolist()
most_important_var
# Out:
# ['EXT_SOURCE_2',
#  'EXT_SOURCE_3',
#  'EXT_SOURCE_1',
#  'CODE_GENDER_F',
#  'CREDIT_TERM']
